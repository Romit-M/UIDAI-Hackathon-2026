# %%
import fireducks.pandas as pd 
from pathlib import Path
import sys
import folium

# %%
PARENT_DIR = Path.cwd().parent
PARENT_DIR
# Out:
# PosixPath('/home/kamal/Desktop/UIDAI-Hackathon-2026')

# %%
df = pd.read_parquet(PARENT_DIR.joinpath("data","processed","master_dataset.parquet"))

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>state</th>
#       <th>district</th>
#       <th>pincode</th>
#       <th>bio_child</th>
#       <th>bio_adult</th>
#       <th>pin_prefix</th>
#       <th>demo_child</th>
#       <th>demo_adult</th>
#       <th>enrol_infant</th>
#       <th>enrol_child</th>
#       <th>enrol_adult</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2025-03-01</td>
#       <td>andamanandnicobarislands</td>
#       <td>nicobar</td>
#       <td>744301</td>
#       <td>101.0</td>
#       <td>48.0</td>
#       <td>744</td>
#       <td>16.0</td>
#       <td>180.0</td>
# ...

# %%
df.isnull().sum()
# Out:
# date            0
# state           0
# district        0
# pincode         0
# bio_child       0
# bio_adult       0
# pin_prefix      0
# demo_child      0
# demo_adult      0
# enrol_infant    0
# enrol_child     0
# enrol_adult     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'fireducks.pandas.frame.DataFrame'>
# RangeIndex: 1780606 entries, 0 to 1780605
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          datetime64[ns]
#  1   state         object
#  2   district      object
#  3   pincode       int64
#  4   bio_child     float64
#  5   bio_adult     float64
#  6   pin_prefix    int64
#  7   demo_child    float64
#  8   demo_adult    float64
#  9   enrol_infant  float64
#  10  enrol_child   float64
#  11  enrol_adult   float64
# dtypes: datetime64[ns](1), float64(7), int64(2), object(2)
# memory usage: 165.1+ MB
