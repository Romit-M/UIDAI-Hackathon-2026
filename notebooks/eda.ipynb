# %%
# Cloning GitHub repo
# !git clone https://github.com/Romit-M/UIDAI-Hackathon-2026.git

# IMPORTS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# HELPER FUNCTIONS

# Data loader
def load_data(file_path):
  df = pd.read_csv(file_path)
  df.columns = df.columns.str.lower()
  return df

# EDA: Shape and schema
def eda(df, df_name):
  print("\n")
  print(f"Showing EDA for {df_name} dataset \n")
  print(f"Shape: {df.shape}\n")
  print(f"Schema:\n{df.dtypes}\n")
  print(f"Columns:\n{df.columns}\n")
  print(f"Missing values:\n{df.isnull().sum()}\n")
  print(f"Unique states: {df['state'].nunique()}")
  print(f"Unique districts: {df['district'].nunique()}")
  print(f"Unique pincodes: {df['pincode'].nunique()}")
  print('-' * 40)
# Out:
# Cloning into 'UIDAI-Hackathon-2026'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 64 (delta 5), reused 7 (delta 3), pack-reused 51 (from 1)
# Receiving objects: 100% (64/64), 82.54 MiB | 11.63 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# Updating files: 100% (24/24), done.

# %%
# INITIALIZING DATAFRAMES

# Biometric data
file_path = 'UIDAI-Hackathon-2026/data/processed/api_data_aadhar_biometric/api_data_aadhar_biometric_0_500000_cleaned.csv'
df_biometric_data = load_data(file_path)

# Demographic data
file_path = 'UIDAI-Hackathon-2026/data/processed/api_data_aadhar_demographic/api_data_aadhar_demographic_0_500000_cleaned.csv'
df_demographic_data = load_data(file_path)

# Enrollment data
file_path = 'UIDAI-Hackathon-2026/data/processed/api_data_aadhar_enrolment/api_data_aadhar_enrolment_0_500000_cleaned.csv'
df_enrolment_data = load_data(file_path)

# DATASETS EDA

eda(df_biometric_data, 'biometric_0_500000')
eda(df_demographic_data, 'demographic_0_500000')
eda(df_enrolment_data, 'enrolment_0_500000')
# Out:
# Showing EDA for biometric_0_500000 dataset
#
# Shape: (500000, 6)
#
# Schema:
# date            object
# state           object
# district        object
# pincode          int64
# bio_age_5_17     int64
# bio_age_17_      int64
# dtype: object
#
# Columns:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')
#
# Missing values:
# date            0
# state           0
# district        0
# pincode         0
# bio_age_5_17    0
# bio_age_17_     0
# dtype: int64
#
# Unique states: 36
# Unique districts: 912
# Unique pincodes: 19509
# ----------------------------------------
#
#
# Showing EDA for demographic_0_500000 dataset
#
# Shape: (500000, 6)
#
# Schema:
# date             object
# state            object
# district         object
# pincode           int64
# demo_age_5_17     int64
# demo_age_17_      int64
# dtype: object
#
# Columns:
# Index(['date', 'state', 'district', 'pincode', 'demo_age_5_17',
#        'demo_age_17_'],
# ...

# %%
df_demographic_data['state'].unique()
# Out:
# array(['uttarpradesh', 'andhrapradesh', 'gujarat', 'rajasthan',
#        'karnataka', 'westbengal', 'telangana', 'odisha', 'maharashtra',
#        'kerala', 'bihar', 'tamilnadu', 'madhyapradesh', 'assam',
#        'tripura', 'arunachalpradesh', 'punjab', 'jharkhand', 'delhi',
#        'chandigarh', 'chhattisgarh', 'jammuandkashmir', 'mizoram',
#        'nagaland', 'himachalpradesh', 'goa', 'haryana', 'meghalaya',
#        'uttarakhand', 'manipur', 'dadraandnagarhavelianddamananddiu',
#        'puducherry', 'sikkim', 'ladakh', 'andamanandnicobarislands',
#        'lakshadweep', 'darbhanga', 'puttenahalli'], dtype=object)

# %%
# !rm -rf /content/UIDAI-Hackathon-2026
# %cd /content
# Out:
# /content
